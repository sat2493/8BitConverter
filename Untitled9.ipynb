# %%
import os

# %%
if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py

# %%
from thinkdsp import CosSignal, SinSignal

# %%
cos_sig = CosSignal(freq=440, amp=1.0, offset=0)
sin_sig = SinSignal(freq=880, amp=0.5, offset=0)

# %%
cos_sig

# %%
cos_sig.plot()

# %%
from thinkdsp import decorate

decorate(xlabel='Time (s)')
cos_sig.plot()

# %%
mix = sin_sig + cos_sig

# %%
mix

# %%
wave = mix.make_wave(duration=1, start=0, framerate=11025)
wave

# %%
from IPython.display import Audio
audio = Audio(data=wave.ys, rate=wave.framerate)
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.make_audio()
wave.plot()

# %%
print('Number of samples', len(wave.ys))
# Out:
# Number of samples 11025

# %%
print('Timestep in ms', 1 / wave.framerate * 1000)
# Out:
# Timestep in ms 0.09070294784580499

# %%
wave.ys
# Out:
# array([1.        , 1.209102  , 1.29840734, ..., 0.23123485, 0.45530309,
#        0.72834746])

# %%
period = mix.period
segment = wave.segment(start=0, duration=period*3)
period
# Out:
# 0.0022727272727272726

# %%
segment.plot()

# %%
mix.plot()

# %%
wave.normalize()
wave.apodize()
wave.plot()
decorate(xlabel='Time (s)')

# %%
audio1 = Audio(data=wave.ys, rate=wave.framerate)

# %%
audio1
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
